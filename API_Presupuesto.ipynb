# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/DataExtraction/blob/main/API_Presupuesto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
from google.colab import userdata
user_key=userdata.get('PRESUPUESTO_KEY')

# %%
url= 'https://www.presupuestoabierto.gob.ar/api/v1/credito'

headers = {"Authorization": user_key, 'Content-Type': 'application/json'}

data = {
    "title": "Credito vigente por jurisdiccion",
    "columns": [
        "jurisdiccion_id",
        "jurisdiccion_desc",
        "credito_vigente"
    ]
}

response = requests.post(url, headers=headers, json=data)

# %%
response.text
# Out:
# '\ufeffjurisdiccion_id,jurisdiccion_desc,credito_vigente\n1,Poder Legislativo Nacional,541239.720809\n5,Poder Judicial de la Nación,1286856.189005\n10,Ministerio Público,531230.991169\n20,Presidencia de la Nación,253918.120933\n25,Jefatura de Gabinete de Ministros,4502798.025587\n30,Ministerio del Interior,760307.460712\n35,"Ministerio de Relaciones Exteriores, Comercio Internacional y Culto",508712.19039\n40,Ministerio de Justicia,82622.785524\n41,Ministerio de Seguridad,4577337.585009\n45,Ministerio de Defensa,3722343.094465\n50,Ministerio de Economía,6288412.679554\n77,Ministerio de Infraestructura,2686485.854989\n80,Ministerio de Salud,1659908.542553\n88,Ministerio de Capital Humano,49774144.181625\n90,Servicio de la Deuda Pública,10877457.72\n91,Obligaciones a Cargo del Tesoro,6051448.715553\n'

# %%
import pandas as pd
from io import StringIO

pd.read_csv(StringIO(response.text))
# Out:
#     jurisdiccion_id                                  jurisdiccion_desc  \
# 0                 1                         Poder Legislativo Nacional
# 1                 5                        Poder Judicial de la Nación
# 2                10                                 Ministerio Público
# 3                20                           Presidencia de la Nación
# 4                25                  Jefatura de Gabinete de Ministros
# 5                30                            Ministerio del Interior
# 6                35  Ministerio de Relaciones Exteriores, Comercio ...
# 7                40                             Ministerio de Justicia
# 8                41                            Ministerio de Seguridad
# 9                45                              Ministerio de Defensa
# 10               50                             Ministerio de Economía
# 11               77                      Ministerio de Infraestructura
# ...
